# %% [markdown]
# <a href="https://colab.research.google.com/github/FAILBAE/dap-2024/blob/main/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Создал аккаунт в гит хабе. А также авторизовался в гугл копайлоте. Связал аккаунты гита с копайлотом.

# %%
# !ssh-keygen -t rsa -b 4096 -C "something"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa): ^C
